# %%
import warnings
warnings.filterwarnings("ignore")
from transformers import pipeline

# Load summarization pipeline with a BART model
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Prompt user for input
text = input("Enter a long educational article or paragraph:\n")

# Check if input is empty
if not text.strip():
    print("⚠️ No input provided.")
    exit()

# Truncate input (approximate token limit)
if len(text) > 1024:
    text = text[:1024]

# Generate summary
summary = summarizer(text, max_length=150, min_length=25, do_sample=False)

# Display result
print("\n📝 Summary:\n", summary[0]['summary_text'])
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Enter a long educational article or paragraph:
# To summarize long educational texts efficiently, a transformer-based model like BART or T5 can be used through the Hugging Face transformers library. The model processes input text, usually limited to 1024 tokens, and generates a concise version capturing the key points. This is particularly useful in educational applications, enabling quick understanding of lengthy content. By suppressing warnings and using the pipeline API, implementation becomes straightforward, making it accessible even to users with limited deep learning experience.
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from transformers import pipeline

# Load summarization pipeline with a valid T5 model
summarizer = pipeline("summarization", model="t5-base")

# Take user input
text = input("Enter your input: ")

# T5 requires task prefix
formatted_text = "summarize: " + text

# Generate summary
summary = summarizer(formatted_text, max_length=150, min_length=25, do_sample=False)

# Output
print("\n📝 Summary:\n", summary[0]['summary_text'])
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cpu
# Enter your input: To summarize long educational texts efficiently, a transformer-based model like BART or T5 can be used through the Hugging Face transformers library. The model processes input text, usually limited to 1024 tokens, and generates a concise version capturing the key points. This is particularly useful in educational applications, enabling quick understanding of lengthy content. By suppressing warnings and using the pipeline API, implementation becomes straightforward, making it accessible even to users with limited deep learning experience.
# ...
